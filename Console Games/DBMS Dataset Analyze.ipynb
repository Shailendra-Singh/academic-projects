# %%
import pandas as pd
import numpy as np

# %%
from os import path
source_pth = r'C:\Users\Shail\Documents\PythonWorkspace\Notebooks\games_data\output'

# %%
source_pth = r'C:\Users\Shail\Documents\PythonWorkspace\Notebooks\games_data\output'
pth_age = path.join(source_pth,'age_ratings.csv')
pth_con = path.join(source_pth,'consoles.csv')
pth_gcon = path.join(source_pth,'game_console.csv')
pth_gme = path.join(source_pth,'games.csv')
pth_gnr = path.join(source_pth,'genre.csv')
pth_sty = path.join(source_pth,'subscription_types.csv')
pth_subs = path.join(source_pth,'subscriptions.csv')
pth_user = path.join(source_pth,'users.csv')

# %%
cities = pd.read_csv(r'C:\Users\Shail\Downloads\simplemaps_uscities_basicv1.74/uscities.csv', on_bad_lines='skip')

# %%
cities.head()
# Out:
#           city   city_ascii state_id  state_name  county_fips  county_name  \
# 0     New York     New York       NY    New York        36061     New York
# 1  Los Angeles  Los Angeles       CA  California         6037  Los Angeles
# 2      Chicago      Chicago       IL    Illinois        17031         Cook
# 3        Miami        Miami       FL     Florida        12086   Miami-Dade
# 4       Dallas       Dallas       TX       Texas        48113       Dallas
#
#        lat       lng  population  density   source  military  incorporated  \
# 0  40.6943  -73.9249    18713220    10715  polygon     False          True
# 1  34.1139 -118.4068    12750807     3276  polygon     False          True
# 2  41.8373  -87.6862     8604203     4574  polygon     False          True
# 3  25.7839  -80.2102     6445545     5019  polygon     False          True
# 4  32.7936  -96.7662     5743938     1526  polygon     False          True
#
#               timezone  ranking  \
# ...

# %%
output_path = r"C:\Users\Shail\Documents\PythonWorkspace\Notebooks\games_data\output"
cities.to_csv(path.join(output_path,"cities.csv"), sep=',', encoding='utf-8',index=False)

# %%
df_age = pd.read_csv(pth_age)
df_con = pd.read_csv(pth_con)
df_gcon = pd.read_csv(pth_gcon)
df_gme = pd.read_csv(pth_gme)
df_gnr = pd.read_csv(pth_gnr)
df_sty = pd.read_csv(pth_sty)
df_subs = pd.read_csv(pth_subs)
df_user = pd.read_csv(pth_user)

# %%
df_user
# Out:
#              UID FirstName    LastName GamerTag          City  Age  \
# 0             15      Eric  Piatkowski   eripia       Chicago   44
# 1             42     Monty    Williams   monwil  Philadelphia   39
# 2             43     Chris     Whitney   chrwhi    Washington   19
# 3             56      Gary      Payton   garpay         Miami   24
# 4             57      Doug    Christie   douchr        Dallas   23
# ...          ...       ...         ...      ...           ...  ...
# 2146  1962936270    Dionte   Christmas   diochr  Philadelphia   44
# 2147  1962936483       Jan      Vesely   janves    Washington   18
# 2148  1962936489     Brian     Skinner   briski       Memphis   21
# 2149  1962936495    Damien     Wilkins   damwil       Detroit   44
# 2150  1962937827      Matt        Matt   matmat    Sacramento   15
#
#       GamerScore                 State
# 0             67              Illinois
# 1             25          Pennsylvania
# 2             60  District of Columbia
# ...

# %%
max([x for x in df_user['UID'].dropna()])
# Out:
# 1962937827

# %%
df_user.shape
# Out:
# (2151, 8)

# %%
df_user.dropna().shape
# Out:
# (2150, 8)

# %%
df_subs.shape
# Out:
# (317950, 4)
